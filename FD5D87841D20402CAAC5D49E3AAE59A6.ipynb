# %%
# %run retropy.ipynb
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
migdal = convertSeries('5122569@TASE', 'ILS', 'USD')
show(migdal, VT, migdal / VT)
# Out:
# trimmed |start| data from 2008-06-26 [VT] to 2016-01-05 [5122569@TASE TR * ILS/USD@IC TR, <noname>]
# trimmed |end| data from 2018-10-03 [5122569@TASE TR * ILS/USD@IC TR] to 2018-08-10 [VT, <noname>]
# <div id="1e16039f-6f0c-424d-96f0-16173cc3fe94" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '1e16039f-6f0c-424d-96f0-16173cc3fe94',
# ...

# %%
publish()
