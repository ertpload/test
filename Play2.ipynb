# %%
# %run "Retropy_framework.ipynb"
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/Retropy_framework.ipynb in <module>()
#       3 import numbers
#       4
# ----> 5 import pandas as pd
#       6
#       7 import quandl
#
# ModuleNotFoundError: No module named 'pandas'

# %%
SPY = get("SPY")
BND = get("BND")
HTUS = get("HTUS")
VFITX = get("VFITX")
AAPLQ = get("WIKI/AAPL", "Q")
AAPL = get("AAPL")

show(AAPL, AAPLQ, 2, datetime.datetime(2015, 8, 25))
show(SPY, ma(SPY, 200), ta=False)
show(BND, SPY, VFITX)
show(BND/SPY, HTUS/SPY, VFITX/SPY)
# Out:
# <div id="5b4e3b3b-1145-475e-88de-f04c8e75b0ec" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("5b4e3b3b-1145-475e-88de-f04c8e75b0ec", [{"type": "scatter", "x": ["2000-01-03", "2000-01-04", "2000-01-05", "2000-01-06", "2000-01-07", "2000-01-10", "2000-01-11", "2000-01-12", "2000-01-13", "2000-01-14", "2000-01-18", "2000-01-19", "2000-01-20", "2000-01-21", "2000-01-24", "2000-01-25", "2000-01-26", "2000-01-27", "2000-01-28", "2000-01-31", "2000-02-01", "2000-02-02", "2000-02-03", "2000-02-04", "2000-02-07", "2000-02-08", "2000-02-09", "2000-02-10", "2000-02-11", "2000-02-14", "2000-02-15", "2000-02-16", "2000-02-17", "2000-02-18", "2000-02-22", "2000-02-23", "2000-02-24", "2000-02-25", "2000-02-28", "2000-02-29", "2000-03-01", "2000-03-02", "2000-03-03", "2000-03-06", "2000-03-07", "2000-03-08", "200
# ...

# %%
# %%bash
# echo $PWD
# rm -rf __tmp
# mkdir -p __tmp
# cd __tmp
# #git clone https://github.com/ertpload/test.git
# git clone https://github.com/ertpload/test.git
# cd test
# cp ../../Play2.ipynb .
# git add .
# git commit -m "..."
# echo "push"
# git push https://ertpload:1d7668ace66b16bb7c4f90cf0366a6dfeb9a9789@github.com/ertpload/test.git
# Out:
# /home/jovyan
# [master 39a11b2] ...
#  1 file changed, 3 insertions(+), 21 deletions(-)
# push
# Cloning into 'test'...
