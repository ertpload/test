# %%
# %run retropy.ipynb
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
all = [get("IWDA.L@AV"), get("IWDA.L@Y"), get("IWDA@IC")]
all = [price(s) for s in all]
show(all)
# Out:
# trimmed |start| data from 2009-09-29 [IWDA@IC] to 2016-06-29 [IWDA.L@AV, IWDA.L@Y]
# ...

# %%
publish()
